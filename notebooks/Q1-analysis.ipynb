# %% [markdown]
# # What are the most important internal and external features in predicting rental prices?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from numpy import log
import numpy as np

df = pd.read_csv('../data/curated/engineered-data.csv')

# %%
selected_property_types = ['Townhouse', 'House', 'Apartment', 'Unit']

# %%
df.head(20)
# Out:
#        suburb  postcode  price propertyType bedrooms bathrooms parkingSpaces  \
# 0   Melbourne      3000    560    Apartment        2         1             0
# 1   Melbourne      3000    580    Apartment        2         1             0
# 2   Melbourne      3000    450    Apartment        1         1             0
# 3   Melbourne      3000    550    Apartment        2         2             1
# 4   Melbourne      3000    600    Apartment        2         1             0
# 5   Melbourne      3000    650    Apartment        2         2             1
# 6   Melbourne      3000    465    Apartment        1         1             0
# 7   Melbourne      3000    500    Apartment        1         1             0
# 8   Melbourne      3000    590    Apartment        2         1             0
# 9   Melbourne      3000    360    Apartment        2         1             0
# 10  Melbourne      3000    500    Apartment        1         1             0
# 11  Melbourne      3000    650    Apartment        2         2             1
# 12  Melbourne      3000    600    Apartment        2         1             0
# 13  Melbourne      3000    480    Apartment        1         1             0
# 14  Melbourne      3000    750    Apartment        2         2             0
# 15  Melbourne      3000    450    Apartment        1         1             0
# 16  Melbourne      3000    400    Apartment        1         1             0
# 17  Melbourne      3000    410    Apartment        1         1             0
# 18  Melbourne      3000    800    Apartment        2         2             1
# 19  Melbourne      3000    530    Apartment        1         1             0
#
#     studies furnished  closest_primary_distance  ...  \
# 0         0         N                     821.8  ...
# 1         0         Y                    1690.6  ...
# 2         0         N                     786.9  ...
# 3         0         N                    2026.9  ...
# 4         0         Y                    1690.6  ...
# 5         0         N                    1778.6  ...
# 6         0         Y                    1846.4  ...
# 7         0         N                    1430.8  ...
# 8         0         Y                    1729.2  ...
# 9         0         Y                    2144.8  ...
# 10        0         N                    1932.1  ...
# 11        0         Y                    1620.3  ...
# 12        0         N                    1674.1  ...
# 13        0         Y                    1472.3  ...
# 14        0         Y                    1252.2  ...
# 15        0         N                    1890.8  ...
# 16        0         N                    2029.8  ...
# 17        0         N                    1593.1  ...
# 18        0         N                    1408.6  ...
# 19        0         N                    1995.2  ...
#
#     log_closest_park_distance  log_closest_tram_distance  \
# 0                    7.251841                   6.533934
# 1                    7.831419                   5.428029
# 2                    7.256297                   5.473111
# 3                    7.697757                   6.197869
# 4                    7.831419                   5.428029
# 5                    7.865764                   5.754476
# 6                    7.673921                   6.068657
# 7                    7.054363                   6.388729
# 8                    7.793793                   6.619540
# 9                    7.597145                   5.736895
# 10                   7.518064                   5.897429
# 11                   7.803108                   5.058790
# 12                   7.623495                   6.346513
# 13                   7.834076                   6.118317
# 14                   7.165725                   6.452522
# 15                   7.495375                   5.777033
# 16                   6.512785                   5.658785
# 17                   7.583095                   6.385194
# 18                   7.452576                   4.472781
# 19                   7.675035                   5.723912
#
#     log_closest_train_distance  park_walkability  is_primary_school_walkable  \
# 0                     6.820126         $<$1.5 km                    $<$1.5km
# 1                     7.311753           1.5-5km                    $>$1.5km
# 2                     6.865683         $<$1.5 km                    $<$1.5km
# 3                     7.401475           1.5-5km                    $>$1.5km
# 4                     7.311753           1.5-5km                    $>$1.5km
# 5                     6.996864           1.5-5km                    $>$1.5km
# 6                     7.342520           1.5-5km                    $>$1.5km
# 7                     6.313729         $<$1.5 km                    $<$1.5km
# 8                     6.044768           1.5-5km                    $>$1.5km
# 9                     6.252097           1.5-5km                    $>$1.5km
# 10                    5.915663           1.5-5km                    $>$1.5km
# 11                    7.263680           1.5-5km                    $>$1.5km
# 12                    5.789348           1.5-5km                    $>$1.5km
# 13                    6.958258           1.5-5km                    $<$1.5km
# 14                    6.759603         $<$1.5 km                    $<$1.5km
# 15                    5.797576           1.5-5km                    $>$1.5km
# 16                    7.502352         $<$1.5 km                    $>$1.5km
# 17                    5.504518           1.5-5km                    $>$1.5km
# 18                    1.504077           1.5-5km                    $<$1.5km
# 19                    6.034045           1.5-5km                    $>$1.5km
#
#     is_secondary_school_walkable  is_tram_stop_walkable  \
# 0                       $>$1.5km              $<$1.5 km
# 1                       $>$1.5km              $<$1.5 km
# 2                       $>$1.5km              $<$1.5 km
# 3                       $>$1.5km              $<$1.5 km
# 4                       $>$1.5km              $<$1.5 km
# 5                       $>$1.5km              $<$1.5 km
# 6                       $>$1.5km              $<$1.5 km
# 7                       $>$1.5km              $<$1.5 km
# 8                       $>$1.5km              $<$1.5 km
# 9                       $>$1.5km              $<$1.5 km
# 10                      $>$1.5km              $<$1.5 km
# 11                      $>$1.5km              $<$1.5 km
# 12                      $>$1.5km              $<$1.5 km
# 13                      $>$1.5km              $<$1.5 km
# 14                      $>$1.5km              $<$1.5 km
# 15                      $>$1.5km              $<$1.5 km
# 16                      $>$1.5km              $<$1.5 km
# 17                      $>$1.5km              $<$1.5 km
# 18                      $>$1.5km              $<$1.5 km
# 19                      $>$1.5km              $<$1.5 km
#
#     is_train_station_walkable  is_bus_walkable  city
# 0                   $<$1.5 km         $<$200 m  True
# 1                   $<$1.5 km         200m-1km  True
# 2                   $<$1.5 km         200m-1km  True
# 3                     1.5-5km         200m-1km  True
# 4                   $<$1.5 km         200m-1km  True
# 5                   $<$1.5 km         200m-1km  True
# 6                     1.5-5km         200m-1km  True
# 7                   $<$1.5 km         200m-1km  True
# 8                   $<$1.5 km         $<$200 m  True
# 9                   $<$1.5 km         $<$200 m  True
# 10                  $<$1.5 km         200m-1km  True
# 11                  $<$1.5 km         200m-1km  True
# 12                  $<$1.5 km         200m-1km  True
# 13                  $<$1.5 km         200m-1km  True
# 14                  $<$1.5 km         $<$200 m  True
# 15                  $<$1.5 km         200m-1km  True
# 16                    1.5-5km          $>$1 km  True
# 17                  $<$1.5 km         200m-1km  True
# 18                  $<$1.5 km         200m-1km  True
# 19                  $<$1.5 km         $<$200 m  True
#
# [20 rows x 30 columns]

# %%
sns.histplot(data=df, x='zlogCrimerate', log_scale=False)
plt.savefig('../plots/crime-rate.png')

# %%
df.corr()
# Out:
#                             postcode     price   studies  \
# postcode                    1.000000  0.048909 -0.004804
# price                       0.048909  1.000000  0.135581
# studies                    -0.004804  0.135581  1.000000
# closest_primary_distance   -0.005807 -0.033372  0.022078
# closest_secondary_distance  0.012858 -0.058048  0.008500
# closest_train_distance      0.040030 -0.098448  0.036678
# closest_tram_distance       0.066467 -0.204043  0.006869
# cbd_distance                0.315770 -0.200638 -0.006838
# cbd_duration                0.374757 -0.188507 -0.003214
# zlogCrimerate              -0.291318 -0.107526 -0.010876
# closest_bus_distance        0.012984  0.011414  0.010926
# closest_park_distance       0.024591 -0.186788  0.000655
# min_pri_icsea               0.001499  0.281954  0.020482
# min_sec_icsea              -0.041165  0.275127  0.037709
# log_closest_park_distance   0.035810 -0.184970 -0.005237
# log_closest_tram_distance   0.113934 -0.191230 -0.008462
# log_closest_train_distance  0.054153 -0.104201  0.026703
# city                       -0.332996  0.103786  0.029098
#
#                             closest_primary_distance  \
# postcode                                   -0.005807
# price                                      -0.033372
# studies                                     0.022078
# closest_primary_distance                    1.000000
# closest_secondary_distance                  0.384022
# closest_train_distance                      0.396756
# closest_tram_distance                       0.222638
# cbd_distance                                0.156924
# cbd_duration                                0.119696
# zlogCrimerate                               0.093938
# closest_bus_distance                        0.328834
# closest_park_distance                       0.084104
# min_pri_icsea                              -0.048053
# min_sec_icsea                               0.027712
# log_closest_park_distance                   0.057017
# log_closest_tram_distance                   0.141688
# log_closest_train_distance                  0.232329
# city                                        0.053615
#
#                             closest_secondary_distance  \
# postcode                                      0.012858
# price                                        -0.058048
# studies                                       0.008500
# closest_primary_distance                      0.384022
# closest_secondary_distance                    1.000000
# closest_train_distance                        0.495901
# closest_tram_distance                         0.307681
# cbd_distance                                  0.280360
# cbd_duration                                  0.269679
# zlogCrimerate                                -0.040220
# closest_bus_distance                          0.249897
# closest_park_distance                         0.127800
# min_pri_icsea                                -0.105171
# min_sec_icsea                                -0.121468
# log_closest_park_distance                     0.082132
# log_closest_tram_distance                     0.269322
# log_closest_train_distance                    0.301396
# city                                         -0.040882
#
#                             closest_train_distance  closest_tram_distance  \
# postcode                                  0.040030               0.066467
# price                                    -0.098448              -0.204043
# studies                                   0.036678               0.006869
# closest_primary_distance                  0.396756               0.222638
# closest_secondary_distance                0.495901               0.307681
# closest_train_distance                    1.000000               0.547493
# closest_tram_distance                     0.547493               1.000000
# cbd_distance                              0.499279               0.866839
# cbd_duration                              0.461736               0.785640
# zlogCrimerate                            -0.024929               0.163939
# closest_bus_distance                      0.325975               0.158438
# closest_park_distance                     0.220366               0.257890
# min_pri_icsea                            -0.289244              -0.559700
# min_sec_icsea                            -0.240022              -0.530349
# log_closest_park_distance                 0.151859               0.194786
# log_closest_tram_distance                 0.450849               0.791215
# log_closest_train_distance                0.796738               0.456234
# city                                     -0.186836              -0.230210
#
#                             cbd_distance  cbd_duration  zlogCrimerate  \
# postcode                        0.315770      0.374757      -0.291318
# price                          -0.200638     -0.188507      -0.107526
# studies                        -0.006838     -0.003214      -0.010876
# closest_primary_distance        0.156924      0.119696       0.093938
# closest_secondary_distance      0.280360      0.269679      -0.040220
# closest_train_distance          0.499279      0.461736      -0.024929
# closest_tram_distance           0.866839      0.785640       0.163939
# cbd_distance                    1.000000      0.956171      -0.053811
# cbd_duration                    0.956171      1.000000      -0.162171
# zlogCrimerate                  -0.053811     -0.162171       1.000000
# closest_bus_distance            0.080170      0.045788       0.051207
# closest_park_distance           0.371869      0.409217      -0.109898
# min_pri_icsea                  -0.525690     -0.513029      -0.199526
# min_sec_icsea                  -0.550677     -0.571863      -0.026444
# log_closest_park_distance       0.338532      0.382168      -0.147881
# log_closest_tram_distance       0.804544      0.800364      -0.004313
# log_closest_train_distance      0.469959      0.463289      -0.084455
# city                           -0.426700     -0.531579       0.420403
#
#                             closest_bus_distance  closest_park_distance  \
# postcode                                0.012984               0.024591
# price                                   0.011414              -0.186788
# studies                                 0.010926               0.000655
# closest_primary_distance                0.328834               0.084104
# closest_secondary_distance              0.249897               0.127800
# closest_train_distance                  0.325975               0.220366
# closest_tram_distance                   0.158438               0.257890
# cbd_distance                            0.080170               0.371869
# cbd_duration                            0.045788               0.409217
# zlogCrimerate                           0.051207              -0.109898
# closest_bus_distance                    1.000000               0.063353
# closest_park_distance                   0.063353               1.000000
# min_pri_icsea                          -0.054208              -0.275102
# min_sec_icsea                          -0.006259              -0.386480
# log_closest_park_distance               0.013093               0.916937
# log_closest_tram_distance               0.043613               0.321932
# log_closest_train_distance              0.161649               0.211495
# city                                   -0.035335              -0.315168
#
#                             min_pri_icsea  min_sec_icsea  \
# postcode                         0.001499      -0.041165
# price                            0.281954       0.275127
# studies                          0.020482       0.037709
# closest_primary_distance        -0.048053       0.027712
# closest_secondary_distance      -0.105171      -0.121468
# closest_train_distance          -0.289244      -0.240022
# closest_tram_distance           -0.559700      -0.530349
# cbd_distance                    -0.525690      -0.550677
# cbd_duration                    -0.513029      -0.571863
# zlogCrimerate                   -0.199526      -0.026444
# closest_bus_distance            -0.054208      -0.006259
# closest_park_distance           -0.275102      -0.386480
# min_pri_icsea                    1.000000       0.676476
# min_sec_icsea                    0.676476       1.000000
# log_closest_park_distance       -0.256780      -0.383108
# log_closest_tram_distance       -0.558615      -0.544971
# log_closest_train_distance      -0.302986      -0.255549
# city                             0.169219       0.409629
#
#                             log_closest_park_distance  \
# postcode                                     0.035810
# price                                       -0.184970
# studies                                     -0.005237
# closest_primary_distance                     0.057017
# closest_secondary_distance                   0.082132
# closest_train_distance                       0.151859
# closest_tram_distance                        0.194786
# cbd_distance                                 0.338532
# cbd_duration                                 0.382168
# zlogCrimerate                               -0.147881
# closest_bus_distance                         0.013093
# closest_park_distance                        0.916937
# min_pri_icsea                               -0.256780
# min_sec_icsea                               -0.383108
# log_closest_park_distance                    1.000000
# log_closest_tram_distance                    0.279203
# log_closest_train_distance                   0.150563
# city                                        -0.322740
#
#                             log_closest_tram_distance  \
# postcode                                     0.113934
# price                                       -0.191230
# studies                                     -0.008462
# closest_primary_distance                     0.141688
# closest_secondary_distance                   0.269322
# closest_train_distance                       0.450849
# closest_tram_distance                        0.791215
# cbd_distance                                 0.804544
# cbd_duration                                 0.800364
# zlogCrimerate                               -0.004313
# closest_bus_distance                         0.043613
# closest_park_distance                        0.321932
# min_pri_icsea                               -0.558615
# min_sec_icsea                               -0.544971
# log_closest_park_distance                    0.279203
# log_closest_tram_distance                    1.000000
# log_closest_train_distance                   0.446590
# city                                        -0.324317
#
#                             log_closest_train_distance      city
# postcode                                      0.054153 -0.332996
# price                                        -0.104201  0.103786
# studies                                       0.026703  0.029098
# closest_primary_distance                      0.232329  0.053615
# closest_secondary_distance                    0.301396 -0.040882
# closest_train_distance                        0.796738 -0.186836
# closest_tram_distance                         0.456234 -0.230210
# cbd_distance                                  0.469959 -0.426700
# cbd_duration                                  0.463289 -0.531579
# zlogCrimerate                                -0.084455  0.420403
# closest_bus_distance                          0.161649 -0.035335
# closest_park_distance                         0.211495 -0.315168
# min_pri_icsea                                -0.302986  0.169219
# min_sec_icsea                                -0.255549  0.409629
# log_closest_park_distance                     0.150563 -0.322740
# log_closest_tram_distance                     0.446590 -0.324317
# log_closest_train_distance                    1.000000 -0.263534
# city                                         -0.263534  1.000000

# %%
sns.histplot(df, x='closest_primary_distance', log_scale=True)
# Out:
# <AxesSubplot:xlabel='closest_primary_distance', ylabel='Count'>

# %%
sns.histplot(df, x='closest_park_distance', log_scale=True)
# Out:
# <AxesSubplot:xlabel='closest_park_distance', ylabel='Count'>

# %%
sns.histplot(df, x='closest_secondary_distance', log_scale=True)
# Out:
# <AxesSubplot:xlabel='closest_secondary_distance', ylabel='Count'>

# %%
sns.histplot(df, x='closest_tram_distance', log_scale=True)
# Out:
# <AxesSubplot:xlabel='closest_tram_distance', ylabel='Count'>

# %%
df = df[df['closest_bus_distance'] > 0]

# %%
sns.histplot(df, x='closest_bus_distance', log_scale=True)
# Out:
# <AxesSubplot:xlabel='closest_bus_distance', ylabel='Count'>

# %%
rcParams['figure.dpi'] = 200

# %%
sns.histplot(df, x='price', hue='bedrooms', log_scale=True, multiple='stack', hue_order=['1', '2', '3', '4+'], bins=30)
plt.xlabel(r'Weekly Rent (\$) (log-scale)')
plt.xticks([300, 500, 700, 900], labels=['300', '500', '700', '900'])
plt.tight_layout()
plt.savefig('../plots/rent-distn-by-bedrooms.png')

# %% [markdown]
# * More bedrooms -> more rent

# %%
sns.boxplot(data=df, x='price', y='bedrooms', showfliers=False, hue='city', order=['1', '2', '3', '4+'][::-1])
plt.xlabel(r'Weekly Rent (\$)')
# Out:
# Text(0.5, 0, 'Weekly Rent (\\$)')

# %% [markdown]
# * Being in the city increases the effect of having more bedrooms on property rents

# %%
sns.histplot(df, x='price', hue='parkingSpaces', log_scale=True, multiple='stack', bins=30)
plt.xlabel(r'Weekly Rent (\$) (log-scale)')
plt.xticks([300, 500, 700, 900], labels=['300', '500', '700', '900'])
plt.tight_layout()
plt.savefig('../plots/rent-distn-by-parking.png')

# %% [markdown]
# * Properties less than $300 almost never have more than 1 parking space
# * It is rare for a property to have more than 2 parking spaces, when it does, it doesn't seem to impact the rent

# %%
sns.boxplot(data=df, x='price', y='parkingSpaces', showfliers=False, hue='city', order=['0', '1', '2', '3+'][::-1])
plt.xlabel(r'Weekly Rent (\$)')
# Out:
# Text(0.5, 0, 'Weekly Rent (\\$)')

# %% [markdown]
# * City parking spaces are worth more than subruban ones

# %%
sns.histplot(df, x='price', hue='bathrooms', log_scale=True, multiple='stack', bins=30)
plt.xlabel(r'Weekly Rent (\$) (log-scale)')
plt.xticks([300, 500, 700, 900], labels=['300', '500', '700', '900'])
plt.tight_layout()
plt.savefig('../plots/rent-distn-by-bathrooms.png')

# %% [markdown]
# * Affordable properties almost never have more than 1 bathroom.
# * Few properties have more than 2 bathrooms, those which do attract a premium.

# %% [markdown]
# * Townhouses attract a premium
# * Units are more affordable

# %%
sns.histplot(data=df, x='price', hue='furnished', multiple='stack',
             bins=30, log_scale=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
f, ((ax2, ax4)) = plt.subplots(2, 1, figsize=(7, 8), sharex=True, gridspec_kw={'height_ratios': [1, 2]})

sns.histplot(data=df, x='price', hue='propertyType', multiple='stack', hue_order=selected_property_types,
             bins=30, log_scale=True, ax=ax4, legend=False)

ax4.set_xlabel(r'Weekly Rent (\$) (log-scale)')
ax4.set_xticks([200, 300, 400, 500, 600, 700, 800, 900], labels=['200', '300', '400', '500', '600', '700', '800', '900'])

sns.boxplot(data=df, x='price', y='propertyType', showfliers=False, order=selected_property_types, ax=ax2)
ax2.set_xlabel('')
ax2.set_ylabel('')

f.savefig('../plots/property-type-boxplot-distplot')

# %%
f, ((ax2, ax4)) = plt.subplots(2, 1, figsize=(7, 8), sharex=True, gridspec_kw={'height_ratios': [1, 2]})

bedroom_order = ['1', '2', '3', '4+'][::-1]

sns.histplot(data=df, x='price', hue='bedrooms', multiple='stack', hue_order=bedroom_order,
             bins=30, log_scale=True, ax=ax4, legend=False)

ax4.set_xlabel(r'Weekly Rent (\$) (log-scale)')
ax4.set_xticks([200, 300, 400, 500, 600, 700, 800, 900], labels=['200', '300', '400', '500', '600', '700', '800', '900'])

sns.boxplot(data=df, x='price', y='bedrooms', showfliers=False, order=bedroom_order, ax=ax2)
ax2.set_xlabel('')
ax2.set_ylabel('Bedrooms', rotation=0)

f.savefig('../plots/bedrooms-boxplot-distplot')

# %%
f, ((ax1, ax2, ax3, ax4)) = plt.subplots(4, 1, figsize=(7, 6), sharex=True)

sns.boxplot(data=df, x='price', y='park_walkability', showfliers=False, ax=ax1)
sns.boxplot(data=df, x='price', y='is_tram_stop_walkable', showfliers=False, ax=ax2)
sns.boxplot(data=df, x='price', y='is_train_station_walkable', showfliers=False, ax=ax3)
sns.boxplot(data=df, x='price', y='is_bus_walkable', showfliers=False, ax=ax4)

ax1.set_title('Park Distance')
ax2.set_title('Tram Stop Distance')
ax3.set_title('Train Station Distance')
ax4.set_title('Bus Stop Distance')

for ax in [ax1, ax2, ax3, ax4]:
    ax.set_xlabel('')
    ax.set_ylabel('')

ax4.set_xlabel(r'Weekly Rent (\$)')

f.suptitle('rich people like parks and trams, not busses')

plt.tight_layout()
plt.savefig('../plots/rent-by-walkability.png')

# %%
f, ((ax1, ax2)) = plt.subplots(2, 1, figsize=(6, 3.5), sharex=True, gridspec_kw={'height_ratios': [1, 1]})

yorder = df['is_primary_school_walkable'].unique()

sns.boxplot(data=df, x='price', y='is_primary_school_walkable', order=yorder, showfliers=False, ax=ax1)
sns.boxplot(data=df, x='price', y='is_secondary_school_walkable', order=yorder, showfliers=False, ax=ax2)

ax1.set_title('Primary School Distance')
ax2.set_title('High School Distance')

for ax in [ax1, ax2]:
    ax.set_xlabel('')
    ax.set_ylabel('')

ax2.set_xlabel(r'Weekly Rent (\$)')

f.suptitle('kids don\'t pay rent')

plt.tight_layout()

plt.savefig('../plots/rent-by-school-walkability.png')

# %%
df.columns
# Out:
# Index(['suburb', 'postcode', 'price', 'propertyType', 'bedrooms', 'bathrooms',
#        'parkingSpaces', 'studies', 'furnished', 'closest_primary_distance',
#        'closest_secondary_distance', 'closest_train_distance',
#        'closest_tram_distance', 'cbd_distance', 'cbd_duration',
#        'zlogCrimerate', 'closest_bus_distance', 'closest_park_distance',
#        'min_pri_icsea', 'min_sec_icsea', 'log_closest_park_distance',
#        'log_closest_tram_distance', 'log_closest_train_distance',
#        'park_walkability', 'is_primary_school_walkable',
#        'is_secondary_school_walkable', 'is_tram_stop_walkable',
#        'is_train_station_walkable', 'is_bus_walkable', 'city'],
#       dtype='object')

# %%
len(df)
# Out:
# 10129

# %%
df['price'].mean()
# Out:
# 522.9514265969

# %%
df.columns
# Out:
# Index(['suburb', 'postcode', 'price', 'propertyType', 'bedrooms', 'bathrooms',
#        'parkingSpaces', 'studies', 'furnished', 'closest_primary_distance',
#        'closest_secondary_distance', 'closest_train_distance',
#        'closest_tram_distance', 'cbd_distance', 'cbd_duration',
#        'zlogCrimerate', 'closest_bus_distance', 'closest_park_distance',
#        'min_pri_icsea', 'min_sec_icsea', 'log_closest_park_distance',
#        'log_closest_tram_distance', 'log_closest_train_distance',
#        'park_walkability', 'is_primary_school_walkable',
#        'is_secondary_school_walkable', 'is_tram_stop_walkable',
#        'is_train_station_walkable', 'is_bus_walkable', 'city', 'city_suburb'],
#       dtype='object')

# %%
df2 = df.dropna(subset='zlogCrimerate')
df2['logRent'] = log(df2['price'])
df2['loglogRent'] = log(log(df2['price']))

df2 = df2.groupby(by=['suburb']).mean()

df2['city_suburb'] = df2['cbd_distance'].apply(lambda s: s < 2000)


sns.scatterplot(data=df2, x='zlogCrimerate', y='logRent', hue='city_suburb')
plt.xlabel('Crime Metric')
plt.ylabel(r'Weekly Rent (log(\$))')
# Out:
# Text(0, 0.5, 'Weekly Rent (log(\\$))')

# %%
sns.scatterplot(data=df2, x='min_sec_icsea', y='logRent')
plt.xlim(800, 1200)
plt.xlabel('High School ICSEA')
plt.ylabel(r'Weekly Rent (log(\$))')
# Out:
# Text(0, 0.5, 'Weekly Rent (log(\\$))')
