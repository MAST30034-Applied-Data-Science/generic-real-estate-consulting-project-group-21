# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_rows = 4000

# %%
df = pd.read_csv('../data/curated/realestate_with_closest_distance_duration.csv')

df = df[['id','propertyType','furnished','price','bedrooms','bathrooms','parkingSpaces',
'studies','closest_primary_distance','closest_primary_duration','closest_secondary_distance',
'closest_secondary_duration','closest_train_distance','closest_train_duration','closest_tram_distance',
'closest_tram_duration','closest_bus_distance','closest_bus_duration','closest_park_distance','closest_park_duration']]

# %%
# transform category features to numeric, which are 'propertyType' and 'furnished'
label_encoder = LabelEncoder()
df['propertyType'] = label_encoder.fit_transform(df['propertyType'])
df['furnished'] = label_encoder.fit_transform(df['furnished'])

# %%
corr_mat = df.corr(method='pearson')
upper_corr_mat = corr_mat.where(
    np.triu(np.ones(corr_mat.shape), k=1).astype(np.bool_))
unique_corr_pairs = upper_corr_mat.unstack().dropna() 
sorted_mat = unique_corr_pairs.sort_values()
print(sorted_mat)
# Out:
# bedrooms                    furnished                    -0.205907
# parkingSpaces               furnished                    -0.194681
# closest_tram_distance       price                        -0.189388
# closest_park_duration       price                        -0.182001
# closest_tram_duration       price                        -0.178838
# closest_park_distance       price                        -0.173850
#                             furnished                    -0.158020
# closest_tram_duration       furnished                    -0.147528
# closest_park_duration       furnished                    -0.145727
# closest_tram_distance       furnished                    -0.135649
# furnished                   propertyType                 -0.129868
#                             id                           -0.124430
# closest_train_duration      furnished                    -0.094646
#                             price                        -0.094285
# closest_train_distance      price                        -0.092519
#                             furnished                    -0.091386
# closest_bus_distance        propertyType                 -0.064754
# bathrooms                   furnished                    -0.062525
# closest_bus_duration        propertyType                 -0.058821
# closest_primary_distance    propertyType                 -0.046039
# closest_primary_duration    propertyType                 -0.040554
# closest_secondary_distance  price                        -0.036492
# closest_primary_distance    price                        -0.030600
# closest_secondary_duration  price                        -0.026957
# closest_primary_duration    price                        -0.026342
# closest_park_distance       closest_secondary_duration   -0.020738
# closest_primary_duration    id                           -0.020353
# closest_primary_distance    id                           -0.019099
# closest_secondary_duration  studies                      -0.015923
# price                       propertyType                 -0.013042
# closest_secondary_distance  studies                      -0.012631
# closest_park_distance       closest_secondary_distance   -0.010659
# closest_bus_duration        furnished                    -0.010043
# closest_bus_distance        furnished                    -0.009271
# closest_tram_distance       studies                      -0.004985
# closest_park_duration       closest_secondary_duration   -0.004929
# closest_bus_duration        id                           -0.004451
# closest_tram_duration       studies                      -0.003425
# closest_bus_distance        id                           -0.003202
# studies                     id                            0.000935
# closest_park_duration       closest_secondary_distance    0.002515
# closest_park_distance       studies                       0.002743
# studies                     propertyType                  0.002865
# closest_park_duration       studies                       0.004439
# closest_bus_distance        studies                       0.006664
# closest_secondary_distance  bathrooms                     0.007585
# closest_secondary_duration  bathrooms                     0.008413
# closest_secondary_distance  furnished                     0.008537
# closest_bus_distance        closest_secondary_duration    0.010213
# closest_secondary_duration  furnished                     0.010857
# closest_bus_duration        closest_secondary_distance    0.014514
# closest_primary_duration    parkingSpaces                 0.015734
# closest_bus_distance        closest_secondary_distance    0.016110
# closest_secondary_distance  id                            0.016157
# closest_primary_distance    parkingSpaces                 0.016716
# closest_bus_duration        studies                       0.016753
#                             closest_secondary_duration    0.016946
# closest_train_duration      closest_secondary_duration    0.018058
# closest_secondary_duration  id                            0.018364
# closest_bus_distance        price                         0.021086
#                             parkingSpaces                 0.021115
# closest_train_duration      studies                       0.021188
# closest_train_distance      studies                       0.021663
# closest_park_distance       id                            0.023312
# closest_bus_duration        price                         0.025057
# closest_primary_distance    studies                       0.025687
# closest_bus_duration        parkingSpaces                 0.026437
# closest_secondary_duration  bedrooms                      0.028118
# propertyType                id                            0.028326
# closest_secondary_duration  propertyType                  0.028614
# closest_park_duration       id                            0.028955
# studies                     furnished                     0.029409
# closest_secondary_distance  bedrooms                      0.030464
#                             propertyType                  0.030508
# closest_train_distance      closest_secondary_duration    0.030975
# closest_train_duration      id                            0.031910
#                             closest_secondary_distance    0.032043
# closest_primary_duration    studies                       0.032301
# closest_train_distance      id                            0.034697
# closest_secondary_duration  parkingSpaces                 0.036055
# closest_secondary_distance  parkingSpaces                 0.039218
#                             closest_primary_duration      0.043306
# closest_park_duration       closest_bus_distance          0.043356
# closest_train_distance      closest_secondary_distance    0.049069
# closest_park_distance       closest_bus_distance          0.049824
# closest_secondary_duration  closest_primary_duration      0.050481
# price                       furnished                     0.051272
# closest_secondary_duration  closest_primary_distance      0.053547
# studies                     bedrooms                      0.056766
# closest_secondary_distance  closest_primary_distance      0.056796
# closest_park_distance       closest_bus_duration          0.056832
# closest_bus_distance        bedrooms                      0.057666
# closest_primary_duration    bedrooms                      0.062524
# studies                     parkingSpaces                 0.063055
# closest_park_duration       closest_primary_distance      0.064329
# closest_primary_distance    bedrooms                      0.066038
# closest_bus_duration        bedrooms                      0.066150
# bathrooms                   id                            0.066263
# closest_bus_distance        bathrooms                     0.068180
# closest_park_distance       closest_primary_duration      0.068557
#                             closest_primary_distance      0.070341
# closest_bus_duration        bathrooms                     0.071523
# closest_tram_distance       id                            0.072517
# closest_tram_duration       id                            0.076439
# closest_park_duration       closest_bus_duration          0.083840
# closest_primary_distance    furnished                     0.085681
# closest_park_distance       bathrooms                     0.087535
# closest_tram_distance       closest_secondary_duration    0.088592
# closest_park_duration       bathrooms                     0.091712
# closest_primary_duration    furnished                     0.092683
# price                       id                            0.099171
# closest_park_duration       closest_primary_duration      0.100328
# closest_primary_duration    bathrooms                     0.100619
# closest_train_distance      propertyType                  0.100746
# closest_tram_duration       closest_secondary_duration    0.100776
# closest_primary_distance    bathrooms                     0.106362
# closest_tram_distance       closest_secondary_distance    0.110827
# parkingSpaces               id                            0.112069
# closest_bus_distance        closest_tram_duration         0.113041
# studies                     bathrooms                     0.116520
# bedrooms                    id                            0.117543
# bathrooms                   propertyType                  0.117935
# closest_tram_duration       closest_secondary_distance    0.121054
# closest_train_duration      propertyType                  0.122760
# closest_bus_distance        closest_tram_distance         0.124176
# closest_bus_duration        closest_tram_duration         0.126953
# studies                     price                         0.129331
# closest_bus_duration        closest_tram_distance         0.129703
# parkingSpaces               propertyType                  0.193652
# closest_tram_distance       bathrooms                     0.207545
# closest_park_duration       propertyType                  0.213083
# closest_tram_distance       propertyType                  0.218499
# parkingSpaces               price                         0.218939
# closest_park_distance       propertyType                  0.221388
# closest_tram_duration       bathrooms                     0.221812
# closest_bus_distance        closest_train_duration        0.223154
# closest_park_distance       parkingSpaces                 0.224055
# closest_park_duration       parkingSpaces                 0.225754
# bedrooms                    propertyType                  0.227356
# closest_bus_duration        closest_train_distance        0.228463
#                             closest_train_duration        0.233468
# closest_tram_distance       closest_primary_duration      0.238279
# closest_park_distance       closest_train_distance        0.238542
#                             bedrooms                      0.239124
# closest_tram_duration       closest_primary_distance      0.242369
#                             closest_primary_duration      0.243873
# closest_park_duration       bedrooms                      0.245356
# closest_tram_duration       propertyType                  0.246870
# closest_park_distance       closest_train_duration        0.247063
# closest_train_duration      bathrooms                     0.249167
# closest_park_distance       closest_tram_distance         0.250860
# closest_train_distance      bathrooms                     0.251971
# closest_tram_distance       closest_primary_distance      0.252228
# closest_park_distance       closest_tram_duration         0.253208
# closest_park_duration       closest_train_distance        0.259104
# closest_bus_distance        closest_train_distance        0.271904
# closest_bus_duration        closest_primary_distance      0.274463
# closest_train_distance      parkingSpaces                 0.280528
# closest_park_duration       closest_tram_distance         0.280664
#                             closest_tram_duration         0.284909
# closest_bus_distance        closest_primary_duration      0.292573
# closest_train_duration      parkingSpaces                 0.296025
# closest_park_duration       closest_train_duration        0.296061
# closest_bus_distance        closest_primary_distance      0.311897
# closest_tram_distance       parkingSpaces                 0.314410
# closest_train_duration      closest_primary_distance      0.323595
# closest_bus_duration        closest_primary_duration      0.330685
# closest_train_duration      closest_primary_duration      0.335432
# closest_train_distance      closest_primary_duration      0.335560
# closest_tram_duration       parkingSpaces                 0.337185
# parkingSpaces               bathrooms                     0.344930
# closest_train_distance      bedrooms                      0.371562
#                             closest_primary_distance      0.380164
# closest_train_duration      bedrooms                      0.381236
# closest_tram_distance       bedrooms                      0.385182
# closest_tram_duration       bedrooms                      0.406100
# bedrooms                    price                         0.420827
# bathrooms                   price                         0.487052
# closest_tram_duration       closest_train_distance        0.536665
# closest_tram_distance       closest_train_distance        0.543496
# parkingSpaces               bedrooms                      0.557378
# closest_tram_distance       closest_train_duration        0.558256
# closest_tram_duration       closest_train_duration        0.558838
# bathrooms                   bedrooms                      0.558907
# closest_primary_duration    closest_primary_distance      0.911128
# closest_bus_duration        closest_bus_distance          0.929105
# closest_park_duration       closest_park_distance         0.941745
# closest_train_duration      closest_train_distance        0.952991
# closest_secondary_duration  closest_secondary_distance    0.975739
# closest_tram_duration       closest_tram_distance         0.977322
# dtype: float64

# %% [markdown]
# Summary:
# Under preliminary analysis, which is single feature pearson relationship with price, the most correlated featues are bedrooms and bathrooms, and it is not suprising.
# Moreover, we have find out that the correlation between duration and distance is highly correlated, which means feature selection should be implemented in modelling step.
