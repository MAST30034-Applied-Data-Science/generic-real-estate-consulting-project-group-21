# %% [markdown]
# # What are the most liveable and affordable suburbs according to your chosen metrics?

# %%
import pandas as pd

df = pd.read_csv('../data/curated/engineered-data.csv')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
from matplotlib import rcParams

rcParams['figure.dpi'] = 200

sns.boxplot(data=df, x='price', y='park_walkability', showfliers=False)
plt.xlabel('Weekly Rent (\$)')
plt.tight_layout()
plt.savefig('../plots/rent-by-park-walkability.png')

# %%
sns.boxplot(data=df, x='price', y='is_primary_school_walkable', showfliers=False)
plt.xlabel('Weekly Rent (\$)')
plt.tight_layout()
plt.savefig('../plots/rent-by-primary-school-walkability.png')

# %%
sns.boxplot(data=df, x='price', y='is_secondary_school_walkable', showfliers=False)
plt.xlabel('Weekly Rent (\$)')
plt.tight_layout()
plt.savefig('../plots/rent-by-secondary-school-walkability.png')

# %%
sns.boxplot(data=df, x='price', y='is_tram_stop_walkable', showfliers=False)
plt.xlabel('Weekly Rent (\$)')
plt.tight_layout()
plt.savefig('../plots/rent-by-tram-service.png')

# %%
suburbf = df.groupby(by='suburb').count()

# %% [markdown]
# remove suburbs with less than 25 properties listed, removes approx 100 of the 300 original suburbs

# %%
selected_suburbs = suburbf[suburbf['postcode'] > 10].index.unique()
