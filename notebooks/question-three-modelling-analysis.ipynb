# %% [markdown]
# # What are the most liveable and affordable suburbs according to your chosen metrics?

# %%
import pandas as pd

df = pd.read_csv('../data/curated/engineered-data.csv')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
from matplotlib import rcParams

rcParams['figure.dpi'] = 200

sns.histplot(df, x='price', hue='park_walkability', log_scale=True, multiple='stack')
plt.xlabel('Weekly Rent (\$) (log-scale)')
plt.xticks([300, 500, 700,  900], labels=['300', '500', '700', '900'])
plt.savefig('../plots/rent-distn-by-bedrooms.png')

# %%
sns.histplot(df, x='price', hue='is_primary_school_walkable', log_scale=True, multiple='stack')
plt.xlabel('Weekly Rent (\$) (log-scale)')
plt.xticks([300, 500, 700,  900], labels=['300', '500', '700', '900'])
plt.savefig('../plots/rent-distn-by-bedrooms.png')

# %%
suburbf = df.groupby(by='suburb').count()

# %% [markdown]
# remove suburbs with less than 25 properties listed, removes approx 100 of the 300 original suburbs

# %%
selected_suburbs = suburbf[suburbf['postcode'] > 10].index.unique()
