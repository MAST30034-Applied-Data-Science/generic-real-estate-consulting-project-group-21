# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import log
from statsmodels.formula.api import ols

df = pd.read_csv('../data/curated/ques2data.csv')
df = df[(df['Type'] == 'All properties') | (df['Year'] > 2020)]

print(len(df['suburb'].unique()))
df = df.drop('Type', axis=1)
df.loc[:, 'Median_Price'] = df['Median_Price'].apply(pd.to_numeric, errors='coerce')
df = df.dropna(subset=['population', 'income'], axis=0)
print(len(df['suburb'].unique()))
df.columns
# Out:
# 384
# 312
# Index(['suburb', 'Year', 'population', 'income', 'Median_Price'], dtype='object')

# %%
known_suburbs = df[df['Year'] <= 2020]['suburb'].unique()

df = df[df['suburb'].isin(known_suburbs)]

print(len(df['suburb'].unique()))
# Out:
# 144

# %%
df.loc[:, 'income_pct_change'] = df.groupby('suburb')['income'].apply(pd.Series.pct_change) + 1
df.loc[:, 'income_change'] = df.groupby('suburb')['income_pct_change'].apply(pd.Series.cumprod) - 1

df.loc[:, 'pop_pct_change'] = df.groupby('suburb')['population'].apply(pd.Series.pct_change) + 1
df.loc[:, 'population_change'] = df.groupby('suburb')['pop_pct_change'].apply(pd.Series.cumprod) - 1
df.drop(['income_pct_change', 'pop_pct_change'], axis=1, inplace=True)

# %%
model = ols(formula="""Median_Price ~ suburb + income_change + population_change""",
            data=df)

model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Median_Price   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     76.59
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):          2.15e-240
# Time:                        22:34:40   Log-Likelihood:                -2268.6
# No. Observations:                 576   AIC:                             4829.
# Df Residuals:                     430   BIC:                             5465.
# Df Model:                         145
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     443.1609      7.627     58.102      0.000     428.169     458.152
# suburb[T.Albert Park]         105.5010     10.340     10.203      0.000      85.177     125.825
# suburb[T.Alphington]          -47.6795     10.350     -4.607      0.000     -68.023     -27.336
# suburb[T.Altona]              -72.0784     10.250     -7.032      0.000     -92.225     -51.932
# suburb[T.Armadale]             28.5547     10.354      2.758      0.006       8.203      48.906
# suburb[T.Ascot Vale]          -22.5062     10.354     -2.174      0.030     -42.857      -2.155
# suburb[T.Ashburton]            -3.5651     10.291     -0.346      0.729     -23.792      16.661
# suburb[T.Aspendale]           -31.6141     10.350     -3.054      0.002     -51.957     -11.271
# suburb[T.Avondale Heights]    -51.5172     10.298     -5.003      0.000     -71.758     -31.276
# suburb[T.Balwyn]               74.5702     10.337      7.214      0.000      54.253      94.887
# suburb[T.Bayswater]           -75.5746     10.343     -7.306      0.000     -95.905     -55.245
# suburb[T.Beaumaris]           110.4537     10.376     10.646      0.000      90.061     130.847
# suburb[T.Bentleigh]            23.6605     10.244      2.310      0.021       3.525      43.796
# suburb[T.Blackburn]           -26.3304     10.327     -2.550      0.011     -46.629      -6.032
# suburb[T.Boronia]             -81.3054     10.286     -7.904      0.000    -101.523     -61.088
# suburb[T.Box Hill]            -39.4126     10.221     -3.856      0.000     -59.502     -19.323
# suburb[T.Brighton]            190.4287     10.416     18.282      0.000     169.955     210.902
# suburb[T.Brighton East]       237.4377     10.355     22.930      0.000     217.085     257.791
# suburb[T.Broadmeadows]        -98.6279     10.256     -9.616      0.000    -118.786     -78.470
# suburb[T.Vermont]              -7.8589     10.353     -0.759      0.448     -28.207      12.490
# suburb[T.Wantirna]            -19.3464     10.383     -1.863      0.063     -39.753       1.061
# suburb[T.Werribee]           -125.2953     10.253    -12.220      0.000    -145.448    -105.142
# suburb[T.West Footscray]      -74.9447     10.321     -7.261      0.000     -95.231     -54.658
# suburb[T.West Melbourne]      -90.4454     10.863     -8.326      0.000    -111.796     -69.094
# suburb[T.Williamstown]         49.6577     10.342      4.802      0.000      29.330      69.985
# suburb[T.Windsor]             -23.1361     10.466     -2.211      0.028     -43.707      -2.565
# suburb[T.Yarraville]           10.2574     10.317      0.994      0.321     -10.020      30.535
# income_change                 110.7413      9.652     11.473      0.000      91.770     129.713
# population_change             255.6864     27.279      9.373      0.000     202.070     309.303
# ==============================================================================
# Omnibus:                       62.742   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              214.086
# Skew:                          -0.465   Prob(JB):                     3.25e-47
# Kurtosis:                       5.838   Cond. No.                         149.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
future_df = df[df['Year'] > 2020]

# %%
future_df.loc[:, 'Median_Price'] = model.fit().predict(future_df)
# Out:
# /tmp/ipykernel_3478/533681087.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future_df.loc[:, 'Median_Price'] = model.fit().predict(future_df)

# %%
future_df.sort_values('income_change')
# Out:
#               suburb  Year    population         income  Median_Price  \
# 5649  Port Melbourne  2025  18137.345904   43602.287980    566.406062
# 5648  Port Melbourne  2024  18016.178669   44257.012448    565.256083
# 5647  Port Melbourne  2023  17895.123755   46621.494706    565.849841
# 5646  Port Melbourne  2022  17773.459914   50930.818986    568.416043
# 5645  Port Melbourne  2021  17652.756421   57346.293187    573.142577
# ...              ...   ...           ...            ...           ...
# 4555         Mentone  2021  13331.031292  136024.216986    471.244901
# 4556         Mentone  2022  13258.049977  169081.747885    524.594547
# 4557         Mentone  2023  13185.098940  218402.637071    604.861552
# 4558         Mentone  2024  13112.132501  294503.446082    729.450577
# 4559         Mentone  2025  13039.170841  416283.072192    929.640761
#
#       income_change  population_change
# 5649      -0.598832           0.063782
# 5648      -0.592808           0.056675
# 5647      -0.571054           0.049575
# 5646      -0.531405           0.042439
# 5645      -0.472379           0.035360
# ...             ...                ...
# 4555       1.032918          -0.026645
# 4556       1.526971          -0.031973
# 4557       2.264085          -0.037300
# 4558       3.401432          -0.042628
# 4559       5.221460          -0.047955
#
# [720 rows x 7 columns]

# %%
df.loc[df['Year'] > 2020, 'Median_Price'] = model.fit().predict(df[df['Year'] > 2020])

# %%
df[df['Year'] > 2020]
# Out:
#           suburb  Year    population         income  Median_Price  \
# 35    Abbotsford  2021   9337.364459   87739.135073    480.788008
# 36    Abbotsford  2022   9404.488164   92916.656874    490.641225
# 37    Abbotsford  2023   9878.605420   99085.265448    513.776344
# 38    Abbotsford  2024  10022.687593  106485.898547    529.252082
# 39    Abbotsford  2025  10190.912148  115433.759061    547.790376
# ...          ...   ...           ...            ...           ...
# 7435  Yarraville  2021  15910.505666   91911.558135    476.045022
# 7436  Yarraville  2022  15908.663387   96980.309295    483.379130
# 7437  Yarraville  2023  15907.936920  102997.167982    492.108535
# 7438  Yarraville  2024  15906.499919  110186.147542    502.529343
# 7439  Yarraville  2025  15905.192434  118838.317169    515.077899
#
#       income_change  population_change
# 35         0.210807           0.055858
# 36         0.282257           0.063448
# 37         0.367385           0.117061
# 38         0.469514           0.133353
# 39         0.592995           0.152376
# ...             ...                ...
# 7435       0.205745          -0.000617
# 7436       0.272240          -0.000733
# 7437       0.351172          -0.000778
# 7438       0.445481          -0.000868
# 7439       0.558985          -0.000951
#
# [720 rows x 7 columns]

# %%
sub_postcodeinfo = pd.read_csv('../data/raw/realestate.csv')
sub_postcodeinfo = sub_postcodeinfo[['suburb', 'postcode']]
sub_postcode = sub_postcodeinfo.groupby(['suburb', 'postcode']).count().reset_index()
sub_postcode
df = df.merge(sub_postcode, on='suburb', how='inner')
df
# Out:
#           suburb  Year    population         income  Median_Price  \
# 0     Abbotsford  2016   8843.391594   72463.341789    450.000000
# 1     Abbotsford  2017   9360.969572   75929.483052    450.000000
# 2     Abbotsford  2018   9595.265665   78784.652725    475.000000
# 3     Abbotsford  2019   9661.113233   81883.887314    495.000000
# 4     Abbotsford  2020   9738.337037   86715.715407    490.000000
# ...          ...   ...           ...            ...           ...
# 1445  Yarraville  2021  15910.505666   91911.558135    476.045022
# 1446  Yarraville  2022  15908.663387   96980.309295    483.379130
# 1447  Yarraville  2023  15907.936920  102997.167982    492.108535
# 1448  Yarraville  2024  15906.499919  110186.147542    502.529343
# 1449  Yarraville  2025  15905.192434  118838.317169    515.077899
#
#       income_change  population_change  postcode
# 0               NaN                NaN      3067
# 1          0.047833           0.058527      3067
# 2          0.087235           0.085021      3067
# 3          0.130004           0.092467      3067
# 4          0.196684           0.101199      3067
# ...             ...                ...       ...
# 1445       0.205745          -0.000617      3013
# 1446       0.272240          -0.000733      3013
# 1447       0.351172          -0.000778      3013
# 1448       0.445481          -0.000868      3013
# 1449       0.558985          -0.000951      3013
#
# [1450 rows x 8 columns]

# %%
df = df[df['Year'].isin([2022, 2025])]
df.loc[:, 'Median_Price_Change'] = df.groupby('suburb')['Median_Price'].apply(pd.Series.pct_change)
df.dropna(inplace=True)
df = df[['Median_Price_Change', 'suburb', 'postcode', 'Median_Price']]
df.to_csv('../data/curated/2025estimates.csv', index=False)
# Out:
# /tmp/ipykernel_3478/2399334478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Median_Price_Change'] = df.groupby('suburb')['Median_Price'].apply(pd.Series.pct_change)
# /tmp/ipykernel_3478/2399334478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
highest_growth_df = df.sort_values('Median_Price_Change').tail(11)
highest_growth_df
# Out:
#       Median_Price_Change            suburb  postcode  Median_Price
# 888              0.120442         Melbourne      3000    531.802452
# 369              0.123110           Clayton      3168    418.955355
# 1089             0.130755         Parkville      3052    449.013863
# 409              0.137765       Collingwood      3066    559.044234
# 1029             0.146711   North Melbourne      3051    489.086321
# 1419             0.147742    West Melbourne      3003    538.689280
# 749              0.167294  Hoppers Crossing      3029    492.926202
# 279              0.174685           Carlton      3053    436.221906
# 419              0.179983       Craigieburn      3064    538.581250
# 1189             0.184531     Roxburgh Park      3064    527.331250
# 899              0.772113           Mentone      3194    929.640761

# %%
# discard Mentone, becasue it seems like an outlier

list(highest_growth_df[0:10]['suburb'])[::-1]
# Out:
# ['Roxburgh Park',
#  'Craigieburn',
#  'Carlton',
#  'Hoppers Crossing',
#  'West Melbourne',
#  'North Melbourne',
#  'Collingwood',
#  'Parkville',
#  'Clayton',
#  'Melbourne']
